# %% [markdown]
# ##Importing Data

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import csv
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import os

# %%
# !unzip -q images_2_rs.zip
# Out:
# replace images_2_rs/img_0.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
os.rename('images_2_rs', 'images')

# %%
df = pd.read_csv('image_points.csv')

def modify_name(name):
  name_ = "images/"+name.split('\\')[-1]
  return name_
df['img_paths'] = df['img_paths'].apply(modify_name)
train_val_data, test_data = train_test_split(df, test_size=0.12, random_state=42)
train_data, val_data = train_test_split(train_val_data, test_size=0.12, random_state=42)
img_df = pd.DataFrame(train_data['img_paths'].to_numpy(),columns=['path'])

# %%
df = pd.read_csv('image_points.csv')

def modify_name(name):
  name_ = "images/"+name.split('\\')[-1]
  return name_
df['img_paths'] = df['img_paths'].apply(modify_name)
train_val_data, test_data = train_test_split(df, test_size=0.12, random_state=42)
train_data, val_data = train_test_split(train_val_data, test_size=0.12, random_state=42)
img_df = pd.DataFrame(train_data['img_paths'].to_numpy(),columns=['path'])

# %%
test_df = test_data
img_df = pd.DataFrame(test_df['img_paths'].to_numpy(),columns=['path'])

# %% [markdown]
# ### Visualizing Actual Data

# %%
row = 0 #row less than 1559
plt.figure(figsize=(10, 10))
outer_color = 'green'

for i in range(16):
    ax = plt.subplot(4, 4, i + 1)
    img_path = img_df.iloc[row+i,:][0]
    image = cv2.imread(img_path)

    #pt 1
    plt.plot(test_df.iloc[row+i][0],test_df.iloc[row+i][1],marker='.',markersize=5,color=outer_color)


    #pt 2
    plt.plot(test_df.iloc[row+i][2],test_df.iloc[row+i][3],marker='.',markersize=5,color=outer_color)

    #pt 3
    plt.plot(test_df.iloc[row+i][4],test_df.iloc[row+i][5],marker='.',markersize=5,color=outer_color)

    plt.plot(test_df.iloc[row+i][6],test_df.iloc[row+i][7],marker='.',markersize=5,color=outer_color)

    plt.plot(test_df.iloc[row+i][8],test_df.iloc[row+i][9],marker='.',markersize=5,color=outer_color)


    plt.imshow(image)

# %%
row=0
i=2
img_path = img_df.iloc[row+i][0]
image = cv2.imread(img_path)
test_df = test_data
outer_color = 'green'
count =0
for x in range(0,10,2):
  y=x+1
  count = count + 1
  plt.plot(test_df.iloc[row+i][x],test_df.iloc[row+i][y],marker='.',markersize=7,color=outer_color)
  plt.text(test_df.iloc[row+i][x], test_df.iloc[row+i][y],'p'+str(count)+'('+str(test_df.iloc[row+i][x])+','+str(test_df.iloc[row+i][y])+')', ha='left', va='bottom')


plt.savefig('exp2_1.png')
plt.imshow(image)

# %%
test_df.iloc[2:]
# Out:
#       x2_1  y2_1  x2_2  y2_2  x2_3  y2_3  x2_4  y2_4  x2_5  y2_5  \
# 1505    97   115   117    98   122    36    68    64    39    98
# 1956    83   154   164   108   135    29    53    43    21   113
# 2091    95   156   137   104   135    35    60    50    38   101
# 321     77   121   155   104   108    58    30    37    57   109
# 2378   105   147   127   101   130    57    55    53    48    93
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 800     76   136   140    92   117    51    38    50    51   100
# 73      90   128   130   103   114    50    69    71    51    94
# 1444    81   168   174   106   144    14    52    41     5   109
# 2193    79   144   145    91   125    64    54    19    37   107
# 1436    80   135   168   112   114    46    60    29    45   113
#
#                 img_paths
# 1505  images/img_1611.png
# 1956  images/img_2062.png
# 2091  images/img_2197.png
# 321    images/img_326.png
# 2378  images/img_2484.png
# ...                   ...
# 800    images/img_889.png
# 73      images/img_75.png
# 1444  images/img_1550.png
# 2193  images/img_2299.png
# 1436  images/img_1542.png
#
# [286 rows x 11 columns]

# %% [markdown]
# ##Load the Images into a generator

# %%
class CustomDataGen(tf.keras.utils.Sequence):
    
    def __init__(self, df, X_col, y_col,
                 batch_size,
                 input_size=(180, 180, 3),
                 shuffle=True):
        
        self.df = df.copy()
        self.X_col = X_col
        self.y_col = y_col
        self.batch_size = batch_size
        self.input_size = input_size
        self.shuffle = shuffle
        
        self.n = len(self.df)
        self.n_x1c = df[y_col['x1c']].nunique()
        self.n_y1c = df[y_col['y1c']].nunique()

        self.n_x2c = df[y_col['x2c']].nunique()
        self.n_y2c = df[y_col['y2c']].nunique()
        
        self.n_x3c = df[y_col['x3c']].nunique()
        self.n_y3c = df[y_col['y3c']].nunique()

        self.n_x4c = df[y_col['x4c']].nunique()
        self.n_y4c = df[y_col['y4c']].nunique()
        
        self.n_x5c = df[y_col['x5c']].nunique()
        self.n_y5c = df[y_col['y5c']].nunique()
      
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __get_input(self, path, target_size):
    
      
        image = tf.keras.preprocessing.image.load_img(path)
        image_arr = tf.keras.preprocessing.image.img_to_array(image)

        return image_arr/255
    
    
    def __get_data(self, batches):
            # Generates data containing batch_size samples

            path_batch = batches[self.X_col['path']]
            
            #pt1
            x1c = batches[self.y_col['x1c']]
            y1c= batches[self.y_col['y1c']]
            x2c = batches[self.y_col['x2c']]
            y2c= batches[self.y_col['y2c']]
            x3c = batches[self.y_col['x3c']]
            y3c= batches[self.y_col['y3c']]
            x4c = batches[self.y_col['x4c']]
            y4c= batches[self.y_col['y4c']]
            x5c = batches[self.y_col['x5c']]
            y5c= batches[self.y_col['y5c']]

            
         
            X_batch = np.asarray([self.__get_input(x, self.input_size) for x in path_batch],dtype=np.float32)
            y_batch = np.asarray([(x, y,z,w,a,b,c,d,e,f) for x, y,z,w,a,b,c,d,e,f in zip(y1c, x1c,y2c,x2c,y3c,x3c,y4c,x4c,y5c,x5c)],dtype=np.float32)
            y_batch = y_batch/180


            return X_batch, y_batch
 

        
    def __getitem__(self, index):
            
            batches = self.df[index * self.batch_size:(index + 1) * self.batch_size]
            X, y = self.__get_data(batches)        
            return X, y
        
    def __len__(self):
            return self.n // self.batch_size

# %%
input_shape = (180,180,3)

traingen = CustomDataGen(train_data,
                         X_col={'path':'img_paths'},
                         y_col={'x1c': 'x2_1', 
                                'y1c': 'y2_1',
                                'x2c': 'x2_2',
                                'y2c': 'y2_2',
                                'x3c': 'x2_3',
                                'y3c': 'y2_3',
                                'x4c': 'x2_4',
                                'y4c': 'y2_4',
                                'x5c': 'x2_5',
                                'y5c': 'y2_5'
                                },
                         batch_size=32, input_size=input_shape)
X, y= traingen[0]

# %%
testgen = CustomDataGen(test_data,
                         X_col={'path':'img_paths'},
                         y_col={'x1c': 'x2_1', 
                                'y1c': 'y2_1',
                                'x2c': 'x2_2',
                                'y2c': 'y2_2',
                                'x3c': 'x2_3',
                                'y3c': 'y2_3',
                                'x4c': 'x2_4',
                                'y4c': 'y2_4',
                                'x5c': 'x2_5',
                                'y5c': 'y2_5'
                                },
                         batch_size=32, input_size=input_shape)

# %%
valgen = CustomDataGen(val_data,
                         X_col={'path':'img_paths'},
                         y_col={'x1c': 'x2_1', 
                                'y1c': 'y2_1',
                                'x2c': 'x2_2',
                                'y2c': 'y2_2',
                                'x3c': 'x2_3',
                                'y3c': 'y2_3',
                                'x4c': 'x2_4',
                                'y4c': 'y2_4',
                                'x5c': 'x2_5',
                                'y5c': 'y2_5'
                                },
                         batch_size=32, input_size=input_shape)

# %% [markdown]
# ##Loss Function

# %%
def euclid_loss(y_true, y_pred):
  loss =  tf.math.reduce_sum(tf.math.squared_difference(y_pred, y_true),axis=1)
  return tf.math.reduce_mean(loss)*10000

# %% [markdown]
# ## Model Architecture

# %%
channel_size = 128
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
        layers.Conv2D(channel_size, kernel_size=(3, 3), strides=(2,2), padding="same", activation="relu"),
       
        layers.Flatten(),
        layers.Dense(channel_size, activation="relu"),
        layers.Dense(channel_size, activation="relu"),
        layers.Dense(channel_size, activation="relu"),
        layers.Dense(channel_size, activation="relu"),
        layers.Dense(channel_size, activation="relu"),
        layers.Dense(channel_size, activation="relu"),
        layers.Dense(channel_size, activation="relu"),
        layers.Dense(channel_size, activation="relu"),

        layers.Dense(10),
    ]
)

opt = keras.optimizers.Adam(learning_rate=0.00001)
model.compile(loss=euclid_loss, optimizer=opt)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 90, 90, 128)       3584
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 128)       147584
#
#  conv2d_2 (Conv2D)           (None, 23, 23, 128)       147584
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       147584
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 128)         147584
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         147584
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 128)         147584
#
#  conv2d_7 (Conv2D)           (None, 1, 1, 128)         147584
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 128)               16512
#
#  dense_7 (Dense)             (None, 128)               16512
#
#  dense_8 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,170,058
# Trainable params: 1,170,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(traingen,validation_data=valgen,
          epochs=100
          )
# Out:
# Epoch 1/100
# 57/57 [==============================] - 17s 43ms/step - loss: 28834.7578 - val_loss: 28034.5977
# Epoch 2/100
# 57/57 [==============================] - 2s 38ms/step - loss: 20780.5840 - val_loss: 7517.4399
# Epoch 3/100
# 57/57 [==============================] - 2s 39ms/step - loss: 4061.1335 - val_loss: 2037.1317
# Epoch 4/100
# 57/57 [==============================] - 2s 38ms/step - loss: 1009.4619 - val_loss: 572.7331
# Epoch 5/100
# 57/57 [==============================] - 2s 38ms/step - loss: 479.5860 - val_loss: 492.4762
# Epoch 6/100
# 57/57 [==============================] - 2s 38ms/step - loss: 456.5888 - val_loss: 472.1268
# Epoch 7/100
# 57/57 [==============================] - 2s 38ms/step - loss: 445.7174 - val_loss: 460.4905
# Epoch 8/100
# 57/57 [==============================] - 2s 38ms/step - loss: 434.0525 - val_loss: 462.5312
# Epoch 9/100
# 57/57 [==============================] - 2s 38ms/step - loss: 421.8881 - val_loss: 438.0022
# Epoch 10/100
# 57/57 [==============================] - 2s 37ms/step - loss: 411.7983 - val_loss: 426.6478
# Epoch 11/100
# 57/57 [==============================] - 2s 38ms/step - loss: 395.5854 - val_loss: 415.6765
# Epoch 12/100
# 57/57 [==============================] - 2s 38ms/step - loss: 382.1877 - val_loss: 392.3740
# Epoch 13/100
# 57/57 [==============================] - 2s 38ms/step - loss: 359.7160 - val_loss: 367.1647
# Epoch 14/100
# 57/57 [==============================] - 2s 37ms/step - loss: 347.9447 - val_loss: 365.5868
# Epoch 15/100
# 57/57 [==============================] - 2s 38ms/step - loss: 333.6109 - val_loss: 356.2083
# Epoch 16/100
# 57/57 [==============================] - 2s 38ms/step - loss: 321.9491 - val_loss: 327.4240
# Epoch 17/100
# 57/57 [==============================] - 2s 38ms/step - loss: 312.6820 - val_loss: 319.3764
# Epoch 18/100
# 57/57 [==============================] - 2s 38ms/step - loss: 304.3641 - val_loss: 325.5933
# Epoch 19/100
# 57/57 [==============================] - 2s 38ms/step - loss: 295.1175 - val_loss: 308.1143
# Epoch 20/100
# 57/57 [==============================] - 2s 38ms/step - loss: 281.5083 - val_loss: 288.6392
# Epoch 21/100
# 57/57 [==============================] - 2s 38ms/step - loss: 272.2519 - val_loss: 276.6657
# Epoch 22/100
# 57/57 [==============================] - 2s 38ms/step - loss: 261.1502 - val_loss: 272.4056
# Epoch 23/100
# 57/57 [==============================] - 2s 38ms/step - loss: 249.6194 - val_loss: 265.5287
# Epoch 24/100
# 57/57 [==============================] - 2s 39ms/step - loss: 239.3064 - val_loss: 252.2103
# Epoch 25/100
# 57/57 [==============================] - 2s 38ms/step - loss: 228.9115 - val_loss: 237.6449
# Epoch 26/100
# 57/57 [==============================] - 2s 39ms/step - loss: 217.2458 - val_loss: 229.0222
# Epoch 27/100
# 57/57 [==============================] - 2s 38ms/step - loss: 209.1386 - val_loss: 219.4312
# Epoch 28/100
# 57/57 [==============================] - 2s 38ms/step - loss: 200.6187 - val_loss: 207.5403
# Epoch 29/100
# 57/57 [==============================] - 2s 38ms/step - loss: 193.0798 - val_loss: 200.1513
# Epoch 30/100
# 57/57 [==============================] - 2s 38ms/step - loss: 182.6024 - val_loss: 192.2030
# Epoch 31/100
# 57/57 [==============================] - 2s 39ms/step - loss: 175.4831 - val_loss: 187.1255
# Epoch 32/100
# 57/57 [==============================] - 2s 38ms/step - loss: 167.1394 - val_loss: 167.7360
# Epoch 33/100
# 57/57 [==============================] - 2s 38ms/step - loss: 160.3291 - val_loss: 167.3379
# Epoch 34/100
# 57/57 [==============================] - 2s 37ms/step - loss: 154.3431 - val_loss: 159.2834
# Epoch 35/100
# 57/57 [==============================] - 2s 38ms/step - loss: 148.0684 - val_loss: 161.3302
# Epoch 36/100
# 57/57 [==============================] - 2s 37ms/step - loss: 144.9653 - val_loss: 157.4337
# Epoch 37/100
# 57/57 [==============================] - 2s 38ms/step - loss: 140.1035 - val_loss: 149.2347
# Epoch 38/100
# 57/57 [==============================] - 2s 37ms/step - loss: 137.6463 - val_loss: 146.8326
# Epoch 39/100
# 57/57 [==============================] - 2s 39ms/step - loss: 134.1546 - val_loss: 140.3192
# Epoch 40/100
# 57/57 [==============================] - 2s 38ms/step - loss: 131.9115 - val_loss: 134.6144
# Epoch 41/100
# 57/57 [==============================] - 2s 38ms/step - loss: 130.5799 - val_loss: 136.1404
# Epoch 42/100
# 57/57 [==============================] - 2s 38ms/step - loss: 128.5665 - val_loss: 132.8113
# Epoch 43/100
# 57/57 [==============================] - 2s 37ms/step - loss: 125.4306 - val_loss: 134.2602
# Epoch 44/100
# 57/57 [==============================] - 2s 39ms/step - loss: 124.8397 - val_loss: 130.4818
# Epoch 45/100
# 57/57 [==============================] - 2s 39ms/step - loss: 122.5908 - val_loss: 126.6895
# Epoch 46/100
# 57/57 [==============================] - 2s 39ms/step - loss: 121.6597 - val_loss: 124.5255
# Epoch 47/100
# 57/57 [==============================] - 2s 38ms/step - loss: 119.0080 - val_loss: 123.8926
# Epoch 48/100
# 57/57 [==============================] - 2s 38ms/step - loss: 119.9692 - val_loss: 118.7699
# Epoch 49/100
# 57/57 [==============================] - 2s 37ms/step - loss: 115.7768 - val_loss: 125.2272
# Epoch 50/100
# 57/57 [==============================] - 2s 37ms/step - loss: 116.1790 - val_loss: 121.5339
# Epoch 51/100
# 57/57 [==============================] - 2s 38ms/step - loss: 114.2433 - val_loss: 125.7874
# Epoch 52/100
# 57/57 [==============================] - 2s 38ms/step - loss: 113.4651 - val_loss: 118.8192
# Epoch 53/100
# 57/57 [==============================] - 2s 38ms/step - loss: 111.6843 - val_loss: 116.2570
# Epoch 54/100
# 57/57 [==============================] - 2s 38ms/step - loss: 111.1825 - val_loss: 120.2894
# Epoch 55/100
# 57/57 [==============================] - 2s 38ms/step - loss: 111.6436 - val_loss: 115.4716
# Epoch 56/100
# 57/57 [==============================] - 2s 38ms/step - loss: 108.3532 - val_loss: 109.9497
# Epoch 57/100
# 57/57 [==============================] - 2s 38ms/step - loss: 107.4887 - val_loss: 108.8818
# Epoch 58/100
# 57/57 [==============================] - 2s 38ms/step - loss: 105.3231 - val_loss: 107.2111
# Epoch 59/100
# 57/57 [==============================] - 2s 38ms/step - loss: 105.4113 - val_loss: 106.9671
# Epoch 60/100
# 57/57 [==============================] - 2s 39ms/step - loss: 105.2070 - val_loss: 111.2187
# Epoch 61/100
# 57/57 [==============================] - 2s 38ms/step - loss: 102.9618 - val_loss: 107.5564
# Epoch 62/100
# 57/57 [==============================] - 2s 39ms/step - loss: 102.3101 - val_loss: 104.4589
# Epoch 63/100
# 57/57 [==============================] - 2s 39ms/step - loss: 102.1894 - val_loss: 102.2626
# Epoch 64/100
# 57/57 [==============================] - 2s 37ms/step - loss: 100.2673 - val_loss: 103.2752
# Epoch 65/100
# 57/57 [==============================] - 2s 37ms/step - loss: 100.2363 - val_loss: 100.9818
# Epoch 66/100
# 57/57 [==============================] - 2s 38ms/step - loss: 99.3376 - val_loss: 100.9083
# Epoch 67/100
# 57/57 [==============================] - 2s 38ms/step - loss: 98.1519 - val_loss: 103.0347
# Epoch 68/100
# 57/57 [==============================] - 2s 39ms/step - loss: 97.4883 - val_loss: 101.6667
# Epoch 69/100
# 57/57 [==============================] - 2s 38ms/step - loss: 97.0511 - val_loss: 100.9918
# Epoch 70/100
# 57/57 [==============================] - 2s 39ms/step - loss: 95.8182 - val_loss: 98.0156
# Epoch 71/100
# 57/57 [==============================] - 2s 39ms/step - loss: 94.3062 - val_loss: 98.6480
# Epoch 72/100
# 57/57 [==============================] - 2s 37ms/step - loss: 95.5803 - val_loss: 97.0353
# Epoch 73/100
# 57/57 [==============================] - 2s 38ms/step - loss: 93.2685 - val_loss: 94.8349
# Epoch 74/100
# 57/57 [==============================] - 2s 38ms/step - loss: 93.8743 - val_loss: 97.6238
# Epoch 75/100
# 57/57 [==============================] - 2s 38ms/step - loss: 91.9570 - val_loss: 95.5909
# Epoch 76/100
# 57/57 [==============================] - 2s 38ms/step - loss: 91.6236 - val_loss: 92.6468
# Epoch 77/100
# 57/57 [==============================] - 2s 38ms/step - loss: 91.8755 - val_loss: 95.2001
# Epoch 78/100
# 57/57 [==============================] - 2s 38ms/step - loss: 89.7003 - val_loss: 94.3806
# Epoch 79/100
# 57/57 [==============================] - 2s 38ms/step - loss: 89.0515 - val_loss: 92.1983
# Epoch 80/100
# 57/57 [==============================] - 2s 39ms/step - loss: 88.9595 - val_loss: 90.5630
# Epoch 81/100
# 57/57 [==============================] - 2s 39ms/step - loss: 86.9326 - val_loss: 87.6858
# Epoch 82/100
# 57/57 [==============================] - 2s 38ms/step - loss: 87.0162 - val_loss: 90.5676
# Epoch 83/100
# 57/57 [==============================] - 2s 38ms/step - loss: 85.8688 - val_loss: 88.8698
# Epoch 84/100
# 57/57 [==============================] - 2s 39ms/step - loss: 84.3696 - val_loss: 88.7366
# Epoch 85/100
# 57/57 [==============================] - 2s 37ms/step - loss: 85.4545 - val_loss: 88.1448
# Epoch 86/100
# 57/57 [==============================] - 2s 38ms/step - loss: 84.2331 - val_loss: 83.7646
# Epoch 87/100
# 57/57 [==============================] - 2s 38ms/step - loss: 83.2838 - val_loss: 84.3355
# Epoch 88/100
# 57/57 [==============================] - 2s 38ms/step - loss: 81.8902 - val_loss: 84.1099
# Epoch 89/100
# 57/57 [==============================] - 2s 39ms/step - loss: 80.8569 - val_loss: 83.8441
# Epoch 90/100
# 57/57 [==============================] - 2s 39ms/step - loss: 80.7309 - val_loss: 82.1728
# Epoch 91/100
# 57/57 [==============================] - 2s 40ms/step - loss: 80.2408 - val_loss: 84.1236
# Epoch 92/100
# 57/57 [==============================] - 2s 39ms/step - loss: 79.6372 - val_loss: 79.3689
# Epoch 93/100
# 57/57 [==============================] - 2s 39ms/step - loss: 78.3847 - val_loss: 81.2406
# Epoch 94/100
# 57/57 [==============================] - 2s 37ms/step - loss: 78.0717 - val_loss: 83.2085
# Epoch 95/100
# 57/57 [==============================] - 2s 38ms/step - loss: 78.3428 - val_loss: 81.3794
# Epoch 96/100
# 57/57 [==============================] - 2s 38ms/step - loss: 77.7067 - val_loss: 81.8340
# Epoch 97/100
# 57/57 [==============================] - 2s 38ms/step - loss: 78.0273 - val_loss: 82.5680
# Epoch 98/100
# 57/57 [==============================] - 2s 39ms/step - loss: 76.0871 - val_loss: 80.7712
# Epoch 99/100
# 57/57 [==============================] - 2s 39ms/step - loss: 75.6602 - val_loss: 74.4331
# Epoch 100/100
# 57/57 [==============================] - 2s 38ms/step - loss: 75.1006 - val_loss: 78.1145

# %%
predicted = model.predict(testgen)
# Out:
# 9/9 [==============================] - 1s 35ms/step

# %% [markdown]
# ###Visualization of the predicted data

# %%
pred_cols = []
for i in range(1,6):
  pred_cols.append('y2_'+str(i))
  pred_cols.append('x2_'+str(i))
pred_cols
# Out:
# ['y2_1',
#  'x2_1',
#  'y2_2',
#  'x2_2',
#  'y2_3',
#  'x2_3',
#  'y2_4',
#  'x2_4',
#  'y2_5',
#  'x2_5']

# %%
pred_df = pd.DataFrame(predicted,columns=pred_cols)
pred_df = (pred_df.iloc[:,:]*180).astype('int')

outer_coords = []
for i in range(1,6):
  outer_coords.append('x2_'+str(i))
  outer_coords.append('y2_'+str(i))
outer_coords.append('img_paths')
df = df[outer_coords]
pred_df = pd.DataFrame(pred_df[outer_coords[:10]].to_numpy(),columns=outer_coords[:10])
pred_df
len(predicted)
# Out:
# 288

# %%
row = 16 #row less than 1559
plt.figure(figsize=(10, 10))
# inner_color= 'purple'
outer_color = 'green'

for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    img_path = img_df.iloc[row+i,:][0]
    image = cv2.imread(img_path)

    #pt 1
    plt.plot(pred_df['x2_1'][row+i],pred_df['y2_1'][row+i],marker='.',markersize=5,color=outer_color)


    #pt 2
    plt.plot(pred_df['x2_2'][row+i],pred_df['y2_2'][row+i],marker='.',markersize=5,color=outer_color)

    #pt3
    plt.plot(pred_df['x2_3'][row+i],pred_df['y2_3'][row+i],marker='.',markersize=5,color=outer_color)

    plt.plot(pred_df['x2_4'][row+i],pred_df['y2_4'][row+i],marker='.',markersize=5,color=outer_color)
    plt.plot(pred_df['x2_5'][row+i],pred_df['y2_5'][row+i],marker='.',markersize=5,color=outer_color)

    plt.imshow(image)

# %%
test_df
# Out:
#       x2_1  y2_1  x2_2  y2_2  x2_3  y2_3  x2_4  y2_4  x2_5  y2_5  \
# 443     79   157   152   108   139    22    54    47    24   111
# 196     75   141   133    99   116    55    48    54    47   105
# 1505    97   115   117    98   122    36    68    64    39    98
# 1956    83   154   164   108   135    29    53    43    21   113
# 2091    95   156   137   104   135    35    60    50    38   101
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 800     76   136   140    92   117    51    38    50    51   100
# 73      90   128   130   103   114    50    69    71    51    94
# 1444    81   168   174   106   144    14    52    41     5   109
# 2193    79   144   145    91   125    64    54    19    37   107
# 1436    80   135   168   112   114    46    60    29    45   113
#
#                 img_paths
# 443    images/img_450.png
# 196    images/img_201.png
# 1505  images/img_1611.png
# 1956  images/img_2062.png
# 2091  images/img_2197.png
# ...                   ...
# 800    images/img_889.png
# 73      images/img_75.png
# 1444  images/img_1550.png
# 2193  images/img_2299.png
# 1436  images/img_1542.png
#
# [288 rows x 11 columns]

# %%
pred_df
# Out:
#      x2_1  y2_1  x2_2  y2_2  x2_3  y2_3  x2_4  y2_4  x2_5  y2_5
# 0      86   160   157   109   140    21    54    47    24   108
# 1      81   142   132    93   120    62    48    50    52    99
# 2      98   121   123   105   119    41    70    64    39    97
# 3      87   157   168   110   136    27    52    38    17   112
# 4      91   153   140   105   131    36    55    53    41   102
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 283    77   135   134    93   117    63    44    41    53   100
# 284    94   127   129   104   112    55    67    61    44   101
# 285    86   166   175   101   139    14    51    42    11   109
# 286    80   143   148    93   120    59    37    23    40   106
# 287    80   132   166    99   117    52    53    31    38   110
#
# [288 rows x 10 columns]

# %% [markdown]
# ###Evaluation of Data

# %%
df_true = test_data.iloc[:,:10]
df_pred = pred_df.iloc[:,:10]
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate the mean squared error (MSE) for all 10 predicted points
mse = mean_squared_error(df_true, df_pred)
print("MSE: ", mse)

# Calculate the root mean squared error (RMSE) for all 10 predicted points
rmse = np.sqrt(mse)
print("RMSE: ", rmse)

# Calculate the mean absolute error (MAE) for all 10 predicted points
mae = mean_absolute_error(df_true, df_pred)
print("MAE: ", mae)

# Calculate the coefficient of determination (R^2) for all 10 predicted points
r2 = r2_score(df_true, df_pred)
print("R^2: ", r2)
# Out:
# MSE:  22.303125
# RMSE:  4.722618447429349
# MAE:  3.5232638888888888
# R^2:  0.7830664129817592

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Calculate the mean squared error (MSE) for all 10 predicted points
mse = mean_squared_error(df_true, df_pred)
print("MSE: ", mse)

# Calculate the root mean squared error (RMSE) for all 10 predicted points
rmse = np.sqrt(mse)
print("RMSE: ", rmse)

# Calculate the mean absolute error (MAE) for all 10 predicted points
mae = mean_absolute_error(df_true, df_pred)
print("MAE: ", mae)

# Calculate the coefficient of determination (R^2) for all 10 predicted points
r2 = r2_score(df_true, df_pred)
print("R^2: ", r2)
# Out:
# MSE:  22.303125
# RMSE:  4.722618447429349
# MAE:  3.5232638888888888
# R^2:  0.7830664129817592

# %%
# train the model and get the training history

# plot the training and validation loss curves
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
